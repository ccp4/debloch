# %% [markdown]
# # Bloch wave Tool
# ### Single Simulation
# - [setup](#Setup-a-bloch-simulation)
# - [diffraction pattern](#Getting-a-diffraction-pattern)
# - [Thickness dependence](#Thickness-dependent-beam)
#
# ### Rocking Curve
# - [setup](#Rocking-curve-setup)
# - [plot the rocking curve](#Plotting-Rocking-curve)

# %%
from utils import*                       ;imp.reload(dsp)
from EDutils import utilities as ut      ;imp.reload(ut)
from debloch import bloch              ;imp.reload(bloch)
from debloch import bloch_pp as bl_rock;imp.reload(bl_rock)
# Out:
# using dpi=96
# using screenszie=[20.0,11.25] inches
# using dpi=96
# using screenszie=[20.0,11.25] inches
# using dpi=96
# using screenszie=[20.0,11.25] inches
# <module 'debloch.bloch_pp' from '/home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/debloch/bloch_pp.py'>

# %% [markdown]
# # Single simulation
# ### Setup a bloch simulation

# %%
b0 = bloch.Bloch('dat/alpha_glycine.cif',path='dat',keV=200,u=[0,3,1],Nmax=8,Smax=0.02,
    thick=100,solve=1)
# Out:
# imported file : dat/alpha_glycine.cif
# ...assembling 147x147 matrix...
# ...diagonalization...
# object saved
# dat/alpha_glycine-1203_200keV_bloch.pkl

# %%
b0.df_G
# Out:
#              h  k  l        qx        qy        qz         q        Sw  \
# (-8, -5, 8) -8 -5  8 -1.147971 -0.467265  1.487652  1.936307 -0.019859
# (-7, -5, 8) -7 -5  8 -0.929030 -0.467265  1.487652  1.815087 -0.014159
# (-6, -5, 8) -6 -5  8 -0.710088 -0.467265  1.487652  1.713380 -0.009660
# (-5, -5, 8) -5 -5  8 -0.491146 -0.467265  1.487652  1.634831 -0.006363
# (-4, -5, 8) -4 -5  8 -0.272205 -0.467265  1.487652  1.582890 -0.004268
# ...         .. .. ..       ...       ...       ...       ...       ...
# (-1, 6, -8) -1  6 -8 -0.823158  0.554749 -1.487652  1.788419  0.015739
# (0, 6, -8)   0  6 -8 -0.604216  0.554749 -1.487652  1.698803  0.019660
# (6, 6, -8)   6  6 -8  0.709434  0.554749 -1.487652  1.739009  0.017926
# (7, 6, -8)   7  6 -8  0.928376  0.554749 -1.487652  1.839222  0.013428
# (8, 6, -8)   8  6 -8  1.147318  0.554749 -1.487652  1.958876  0.007727
#
#                   Swa        px        py                  Vg       Vga  \
# (-8, -5, 8)  0.019859 -1.147971 -1.559073 -0.000405+0.000000j  0.000405
# (-7, -5, 8)  0.014159 -0.929030 -1.559073 -0.001111+0.000000j  0.001111
# (-6, -5, 8)  0.009660 -0.710088 -1.559073  0.001302+0.000000j  0.001302
# (-5, -5, 8)  0.006363 -0.491146 -1.559073  0.001524+0.000000j  0.001524
# (-4, -5, 8)  0.004268 -0.272205 -1.559073 -0.002396-0.000000j  0.002396
# ...               ...       ...       ...                 ...       ...
# (-1, 6, -8)  0.015739 -0.823158  1.586738 -0.000152-0.000000j  0.000152
# (0, 6, -8)   0.019660 -0.604216  1.586738 -0.000773+0.000000j  0.000773
# (6, 6, -8)   0.017926  0.709434  1.586738 -0.000896-0.000000j  0.000896
# (7, 6, -8)   0.013428  0.928376  1.586738  0.000776-0.000000j  0.000776
# (8, 6, -8)   0.007727  1.147318  1.586738  0.003106-0.000000j  0.003106
#
#                   Swl    L  zone                  Sg            Ig  \
# (-8, -5, 8)  8.000000  1.0     3  0.000023-0.000000j  5.111847e-10
# (-7, -5, 8)  8.000000  1.0     3  0.001900-0.000000j  3.611408e-06
# (-6, -5, 8)  8.000000  1.0     3  0.000360+0.000000j  1.295947e-07
# (-5, -5, 8)  8.000000  1.0     3  0.005463+0.000000j  2.984929e-05
# (-4, -5, 8)  8.000000  1.0     3 -0.013712-0.000000j  1.880066e-04
# ...               ...  ...   ...                 ...           ...
# (-1, 6, -8)  1.803012  1.0     8  0.000235+0.000000j  5.537079e-08
# (0, 6, -8)   1.706418  1.0     8  0.000105-0.000000j  1.106020e-08
# (6, 6, -8)   1.746520  1.0     8  0.000760+0.000000j  5.780911e-07
# (7, 6, -8)   1.872003  1.0     8 -0.001277+0.000000j  1.629496e-06
# (8, 6, -8)   2.111971  1.0     8  0.006600-0.000000j  4.356543e-05
#
#                               S             I
# (-8, -5, 8) -0.000642+0.000115j  4.261124e-07
# (-7, -5, 8) -0.000411+0.000476j  3.954170e-07
# (-6, -5, 8)  0.000545+0.001263j  1.892008e-06
# (-5, -5, 8)  0.000516+0.000662j  7.039057e-07
# (-4, -5, 8) -0.011158+0.011534j  2.575257e-04
# ...                         ...           ...
# (-1, 6, -8) -0.000037+0.000129j  1.794471e-08
# (0, 6, -8)   0.000879-0.000499j  1.021766e-06
# (6, 6, -8)   0.000125-0.003607j  1.302578e-05
# (7, 6, -8)  -0.000781-0.000004j  6.106848e-07
# (8, 6, -8)  -0.000444-0.005835j  3.423945e-05
#
# [147 rows x 20 columns]

# %% [markdown]
# ### Getting a diffraction pattern

# %%
b0.convert2tiff(thick=200,Imax=1e5,cutoff=20,show=True)
# Out:
# aperpixel set to 1.0E-02 A^-1
# dat/alpha_glycine-1203_200keV_bloch_100A.tiff saved
# tiff format detected
# 20
# shortcuts :
#         'up or right'  : show frame+1
#         'down or left' : show frame-1
#         ##
#         'p' : increase increment rate
#         'm' : decrease increment rate
#         ##
#         'pageup'   : increae cutoff brightness
#         'pagedown' : decrease cutoff brightness
#         'r'        : reset cutoff brightness
#         ##
#         'ctrl+t' : increase thickness
#         'ctrl+T' : decrease thickness
#         ##
#         'enter' : change settings
#         'S' : save image
#         'h' : show help

# %% [markdown]
# ### Thickness dependent beam

# %%
refl = b0.get_beam(cond=lambda dfG:bl_rock.strong_beams(dfG,tol=0.01,n=5),index=False)
print(refl)
# Out:
# ['(5, 5, -7)', '(2, 0, 0)', '(-2, 0, 0)', '(0, -2, 3)', '(6, -1, 2)']

# %%
b0.show_beams_vs_thickness(thicks=(0,1000,1000),refl=refl,cm='Spectral')
# Out:
# ... beam vs thickness ...
# (<Figure size 960x1080 with 1 Axes>,
#  <AxesSubplot:xlabel='$thickness(\\AA)$', ylabel='$I_{hk}$'>)

# %% [markdown]
# ## Rocking curve
# ### Rocking curve setup

# %%
    bloch_args = {'cif_file':'dat/alpha_glycine.cif','Smax':0.015,'Nmax':8,
        'solve':1,'thick':300,'keV':200}
    uvw = ut.get_uvw_rock(e0=[0,3,1],e1=[2,1],deg=0.5,npts=10,show=0)
    rock = bl_rock.Bloch_cont(path='dat',tag='',uvw=uvw,Sargs=bloch_args)
# Out:
# imported file : dat/alpha_glycine.cif
# ...assembling 117x117 matrix...
# ...diagonalization...
# object saved
# dat/u_0.pkl
# imported file : dat/alpha_glycine.cif
# /home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# ...assembling 116x116 matrix...
# ...diagonalization...
# object saved
# dat/u_1.pkl
# imported file : dat/alpha_glycine.cif
# /home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# ...assembling 110x110 matrix...
# ...diagonalization...
# object saved
# dat/u_2.pkl
# imported file : dat/alpha_glycine.cif
# /home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# ...assembling 106x106 matrix...
# ...diagonalization...
# object saved
# dat/u_3.pkl
# imported file : dat/alpha_glycine.cif
# /home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# ...assembling 104x104 matrix...
# ...diagonalization...
# object saved
# dat/u_4.pkl
# imported file : dat/alpha_glycine.cif
# /home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# ...assembling 109x109 matrix...
# ...diagonalization...
# object saved
# dat/u_5.pkl
# imported file : dat/alpha_glycine.cif
# /home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# ...assembling 106x106 matrix...
# ...diagonalization...
# object saved
# dat/u_6.pkl
# imported file : dat/alpha_glycine.cif
# /home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# ...assembling 111x111 matrix...
# ...diagonalization...
# object saved
# dat/u_7.pkl
# imported file : dat/alpha_glycine.cif
# /home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# ...assembling 108x108 matrix...
# ...diagonalization...
# object saved
# dat/u_8.pkl
# imported file : dat/alpha_glycine.cif
# /home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# ...assembling 101x101 matrix...
# ...diagonalization...
# object saved
# dat/u_9.pkl
# Dataframe saved : dat/df_.pkl
# /home/lii26466/Documents/jupyter/blochwave/.env/lib/python3.9/site-packages/pandas/core/internals/blocks.py:922: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr_value = np.asarray(value)
# ...building index...
# object saved
# dat/rock_.pkl
# object saved
# dat/rock_.pkl
# object saved
# dat/rock_.pkl

# %% [markdown]
# ### Plotting Rocking curve

# %%
    rock = ut.load_pkl(file='dat/rock_.pkl')
    rock.set_beams_vs_thickness((10,200,3),v=0)
    rock.plot_rocking(refl=refl)#cond=lambda dfG:bl_rock.strong_beams(dfG,tol=0.01,n=5),n=5)
# Out:
# ... beam vs thickness ...
# ... beam vs thickness ...
# ... beam vs thickness ...
# ... beam vs thickness ...
# ... beam vs thickness ...
# ... beam vs thickness ...
# ... beam vs thickness ...
# ... beam vs thickness ...
# ... beam vs thickness ...
# ... beam vs thickness ...
# setting thickness to 200A
# removing Friedel pairs
# total number of beams:4
# gathering the intensities
# gathering plots
# (<Figure size 960x1080 with 1 Axes>,
#  <AxesSubplot:xlabel='$S_w(\\AA^{-1})$', ylabel='$I$'>)
